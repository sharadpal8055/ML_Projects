# %% [markdown]
# <a href="https://colab.research.google.com/github/sharadpal8055/ML_Projects/blob/main/toy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("sahilislam007/college-student-placement-factors-dataset")
# Out:
# Using Colab cache for faster access to the 'college-student-placement-factors-dataset' dataset.

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/root/.cache/kagglehub/datasets/sahilislam007/college-student-placement-factors-dataset/versions/1/college_student_placement_dataset.csv')

# %%
df
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0       CLG0030  107             6.61  6.28                     8
# 1       CLG0061   97             5.52  5.37                     8
# 2       CLG0036  109             5.36  5.83                     9
# 3       CLG0055  122             5.47  5.75                     6
# 4       CLG0004   96             7.91  7.69                     7
# ...         ...  ...              ...   ...                   ...
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                       No                       8                     8
# ...

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  object
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  object
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.4+ KB

# %%
df.shape
# Out:
# (10000, 10)

# %%
newdf=df.iloc[:,[3,1,9]]

# %%
newdf.head()
# Out:
#    CGPA   IQ Placement
# 0  6.28  107        No
# 1  5.37   97        No
# 2  5.83  109        No
# 3  5.75  122        No
# 4  7.69   96        No

# %%
df['Placement'] = df['Placement'].map({
    'No': 0,
    'Yes': 1
})

# %%
newdf.head()
# Out:
#    CGPA   IQ Placement
# 0  6.28  107        No
# 1  5.37   97        No
# 2  5.83  109        No
# 3  5.75  122        No
# 4  7.69   96        No

# %%
newdf['Placement'] = newdf['Placement'].map({
    'No': 0,
    'Yes': 1
})
# Out:
# /tmp/ipykernel_481/3779515788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Placement'] = newdf['Placement'].map({

# %%
newdf.head()
# Out:
#    CGPA   IQ  Placement
# 0  6.28  107          0
# 1  5.37   97          0
# 2  5.83  109          0
# 3  5.75  122          0
# 4  7.69   96          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(newdf['CGPA'],newdf['IQ'],c=newdf['Placement'])

# %%
X=newdf.iloc[:,0:2]
Y=newdf.iloc[:,-1]

# %%
X
# Out:
#       CGPA   IQ
# 0     6.28  107
# 1     5.37   97
# 2     5.83  109
# 3     5.75  122
# 4     7.69   96
# ...    ...  ...
# 9995  8.29  119
# 9996  9.34   70
# 9997  6.25   89
# 9998  8.92  107
# 9999  9.77  109
#
# [10000 rows x 2 columns]

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    1
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Placement, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42
)

# %%
X_test
# Out:
#       CGPA   IQ
# 6252  7.24  139
# 4684  8.49   84
# 1731  5.66   94
# 4742  6.29  100
# 4521  6.39  116
# ...    ...  ...
# 6412  7.40   72
# 8285  7.95  114
# 7853  8.81  108
# 1095  9.63   98
# 6929  6.79   83
#
# [2000 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train=StandardScaler().fit_transform(X_train)
X_test=StandardScaler().fit_transform(X_test)

# %%
X_train
# Out:
# array([[-0.38674212,  0.22949886],
#        [-1.70492153, -0.76655391],
#        [-0.3663579 , -0.23532577],
#        ...,
#        [-0.5905843 , -0.70015039],
#        [ 0.02773697,  0.22949886],
#        [-0.7128896 , -1.69620317]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_test
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    0
# 4521    1
#        ..
# 6412    0
# 8285    0
# 7853    0
# 1095    0
# 6929    0
# Name: Placement, Length: 2000, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.8585

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(
    X_train,
    y_train.values,
    clf=model
)

plt.show()

# %%
import pickle

# %%
pickle.dump(model, open('model.pkl', 'wb'))

# %%
import os

print(os.getcwd())
# Out:
# /content

# %%
import os

print(os.path.exists("model.pkl"))
print(os.path.abspath("model.pkl"))
# Out:
# True
# /content/model.pkl
